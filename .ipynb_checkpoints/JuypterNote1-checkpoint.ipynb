# %% [markdown]
# # Juypter NoteBook

# %% [markdown]
# ## Addition
# It is very simple, just like calculator. Two examples are given below

# %%
2+5
# Out:
# 7

# %%
a = 2;
b = 5;
c = a+b;
print(c)
# Out:
# 7

# %%
from matplotlib import pyplot as plt
x = [1,2,3,4,5];
y = [2,5,1,3,1];
plt.plot(x,y)
