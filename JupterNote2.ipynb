# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = np.array((1, 2, 3))
print(n)
# Out:
# [1 2 3]

# %%
print(type(n))
# Out:
# <class 'numpy.ndarray'>

# %%
x = np.arange(0,25,0.1)   # start,stop,step
y = np.sin(x)

# %%
plt.plot(x,y)
